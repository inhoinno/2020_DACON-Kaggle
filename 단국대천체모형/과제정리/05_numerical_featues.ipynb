# %% [markdown]
# <h2>수치형변수 가공 데모</h2>

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from matplotlib import rcParams, pyplot as plt
import numpy as np
import pandas as pd
from pathlib import Path
import seaborn as sns
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from warnings import simplefilter

# %%
rcParams['figure.figsize'] = (16, 8)
plt.style.use('fivethirtyeight')
simplefilter('ignore')

# %% [markdown]
# <h4> 학습 데이터 로드 </h4>

# %%
ls "./Downloads/movies-20200915T114008Z-001/movies"
# Out:
#  C 드라이브의 볼륨: SSD
#  볼륨 일련 번호: BCA4-98AF
#
#  C:\Users\inhoinno\Downloads\movies-20200915T114008Z-001\movies 디렉터리
#
# 2020-09-15  오후 08:40    <DIR>          .
# 2020-09-15  오후 08:40    <DIR>          ..
# 2019-04-29  오후 06:13            26,039 movies_test.csv
# 2019-04-29  오후 06:13            67,137 movies_train.csv
# 2019-04-29  오후 06:13             5,040 submission.csv
#                3개 파일              98,216 바이트
#                2개 디렉터리  117,912,846,336 바이트 남음

# %%
data_dir = Path("./Downloads/movies-20200915T114008Z-001/movies")
trn_file = data_dir / 'movies_train.csv'
seed = 42

# %%
df = pd.read_csv(trn_file, index_col=0)
print(df.shape)
df.head()
# Out:
# (600, 11)
#             distributor genre release_time  time screening_rat director  \
# title
# 개들의 전쟁         롯데엔터테인먼트    액션   2012-11-22    96      청소년 관람불가      조병옥
# 내부자들             (주)쇼박스   느와르   2015-11-19   130      청소년 관람불가      우민호
# 은밀하게 위대하게        (주)쇼박스    액션   2013-06-05   123       15세 관람가      장철수
# 나는 공무원이다         (주)NEW   코미디   2012-07-12   101        전체 관람가      구자홍
# 불량남녀       쇼박스(주)미디어플렉스   코미디   2010-11-04   108       15세 관람가      신근호
#
#            dir_prev_bfnum  dir_prev_num  num_staff  num_actor  box_off_num
# title
# 개들의 전쟁                NaN             0         91          2        23398
# 내부자들           1161602.50             2        387          3      7072501
# 은밀하게 위대하게       220775.25             4        343          4      6959083
# 나는 공무원이다         23894.00             2         20          6       217866
# 불량남녀                 1.00             1        251          2       483387

# %% [markdown]
# <h3>EDA(Exploratory Data Analysis) </h3>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 600 entries, 개들의 전쟁 to 베를린
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   distributor     600 non-null    object
#  1   genre           600 non-null    object
#  2   release_time    600 non-null    object
#  3   time            600 non-null    int64
#  4   screening_rat   600 non-null    object
#  5   director        600 non-null    object
#  6   dir_prev_bfnum  270 non-null    float64
#  7   dir_prev_num    600 non-null    int64
#  8   num_staff       600 non-null    int64
#  9   num_actor       600 non-null    int64
#  10  box_off_num     600 non-null    int64
# dtypes: float64(1), int64(5), object(5)
# memory usage: 56.2+ KB

# %% [markdown]
# <h5> 독립변수를 포함 총 6개의 수치형변수가 있다. 그 중 dir_prev_bfnum은 결측값이 많음을 확인할 수 있다.</h5>

# %%
df.fillna(0, inplace=True) #결측값을 0으로 대체하는 부분
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 600 entries, 개들의 전쟁 to 베를린
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   distributor     600 non-null    object
#  1   genre           600 non-null    object
#  2   release_time    600 non-null    object
#  3   time            600 non-null    int64
#  4   screening_rat   600 non-null    object
#  5   director        600 non-null    object
#  6   dir_prev_bfnum  600 non-null    float64
#  7   dir_prev_num    600 non-null    int64
#  8   num_staff       600 non-null    int64
#  9   num_actor       600 non-null    int64
#  10  box_off_num     600 non-null    int64
# dtypes: float64(1), int64(5), object(5)
# memory usage: 56.2+ KB

# %% [markdown]
# <h5>결측값을 0으로 대체하였다.</h5>

# %%
df.describe()
# Out:
#              time  dir_prev_bfnum  dir_prev_num   num_staff   num_actor  \
# count  600.000000    6.000000e+02    600.000000  600.000000  600.000000
# mean   100.863333    4.726993e+05      0.876667  151.118333    3.706667
# std     18.097528    1.309474e+06      1.183409  165.654671    2.446889
# min     45.000000    0.000000e+00      0.000000    0.000000    0.000000
# 25%     89.000000    0.000000e+00      0.000000   17.000000    2.000000
# 50%    100.000000    0.000000e+00      0.000000   82.500000    3.000000
# 75%    114.000000    3.761416e+05      2.000000  264.000000    4.000000
# max    180.000000    1.761531e+07      5.000000  869.000000   25.000000
#
#         box_off_num
# count  6.000000e+02
# mean   7.081818e+05
# std    1.828006e+06
# min    1.000000e+00
# 25%    1.297250e+03
# 50%    1.259100e+04
# 75%    4.798868e+05
# max    1.426277e+07

# %% [markdown]
# <h5> 수치형변수의 분포로부터 모든 수치형변수가 0이나 양수의 값을 가짐을 알 수 있다.</h5>

# %%
target_col = 'box_off_num'
pred_col = 'pred'
num_cols = [x for x in df.columns if df[x].dtype in [np.int64, np.float64] and x != target_col]
print(num_cols)
# Out:
# ['time', 'dir_prev_bfnum', 'dir_prev_num', 'num_staff', 'num_actor']

# %%
df.box_off_num.hist(bins=50)

# %%
sns.pairplot(data=df, vars=num_cols + [target_col], size=5)

# %% [markdown]
# <h5> comment : "수치형변수 중 time은 정규분포에 가깝고 나머지는 멱함수 (power-law)분포에 가깝다." </h5>

# %%
df.corr().style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_19c4f1c3_f74b_11ea_83d6_001a7dda7113row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_19c4f1c3_f74b_11ea_83d6_001a7dda7113row0_col1 {
#             background-color:  #d4d4e8;
#             color:  #000000;
#         }    #T_19c4f1c3_f74b_11ea_83d6_001a7dda7113row0_col2 {
#             background-color:  #c0c9e2;
#             color:  #000000;
#         }    #T_19c4f1c3_f74b_11ea_83d6_001a7dda7113row0_col3 {
#             background-color:  #4697c4;
#             color:  #000000;
#         }    #T_19c4f1c3_f74b_11ea_83d6_001a7dda7113row0_col4 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_19c4f1c3_f74b_11ea_83d6_001a7dda7113row0_col5 {
#             background-color:  #a7bddb;
#             color:  #000000;
#         }    #T_19c4f1c3_f74b_11ea_83d6_001a7dda7113row1_col0 {
#             background-color:  #e2dfee;
#             color:  #000000;
# ...

# %% [markdown]
# <h3> 선형 회귀 모델 학습 </h3>
# <h4> RMSE/RMLSE 손실함수 정의 </h4>

# %%
rmse = lambda y, p: np.sqrt(mean_squared_error(y, p))
rmlse = lambda y, p: np.sqrt(mean_squared_error(np.log1p(y), np.log1p(p)))
